# %%
import tarfile
import scipy.io
import pandas as pd
import numpy as np
import os
import shutil
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import datasets, layers, models
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
new_mat = scipy.io.loadmat('/content/drive/Shareddrives/apm_cnn_trial/trial_2/cars_annos.mat')#car_annos.mat can be found on the Stanford car dataset
trial = np.hstack(new_mat['annotations'])
trial_df = pd.DataFrame(trial)
trial_df['file_name'] = trial_df['relative_im_path']
trial_df['file_name'] = trial_df['file_name'].map(np.array2string)
trial_df['file_name'] = trial_df['file_name'].map(lambda x:x.lstrip("['car_ims/").rstrip("']"))
trial_df['class_number'] = trial_df['class'].astype(np.float)
names= new_mat['class_names'].copy()
names_df = pd.DataFrame(names).T
names_df['class_number'] =names_df.index+1
names_df['car_name'] = names_df[0].map(lambda x:np.array2string(x).lstrip("['").rstrip("']"))
names_df = names_df.drop(columns = 0)
names_df['brand'] = names_df['car_name'].map(lambda x:x.split()[0])
names_df['model'] = names_df['car_name'].map(lambda x:x.split()[1])
names_df['both']= names_df['brand'] +  names_df['model']
names_df['both'] = names_df['both'].replace('RamC/V','RamCV')

# %%
names_df['both'] = names_df['both'].map(lambda x : x.lower())

# %%
merged_df_2 = trial_df.merge(names_df, left_on='class_number', right_on = 'class_number')

# %%
merged_df_2#this dataframe contains the names of the cars and the file_name of the images
# Out:
#            relative_im_path  bbox_x1 bbox_y1  ...  brand    model         both
# 0      [car_ims/000001.jpg]  [[112]]   [[7]]  ...     AM  General    amgeneral
# 1      [car_ims/000002.jpg]   [[48]]  [[24]]  ...     AM  General    amgeneral
# 2      [car_ims/000003.jpg]    [[7]]   [[4]]  ...     AM  General    amgeneral
# 3      [car_ims/000004.jpg]   [[33]]  [[50]]  ...     AM  General    amgeneral
# 4      [car_ims/000005.jpg]    [[5]]   [[8]]  ...     AM  General    amgeneral
# ...                     ...      ...     ...  ...    ...      ...          ...
# 16180  [car_ims/016181.jpg]   [[38]]  [[36]]  ...  smart   fortwo  smartfortwo
# 16181  [car_ims/016182.jpg]   [[29]]  [[34]]  ...  smart   fortwo  smartfortwo
# 16182  [car_ims/016183.jpg]   [[25]]  [[32]]  ...  smart   fortwo  smartfortwo
# 16183  [car_ims/016184.jpg]   [[56]]  [[60]]  ...  smart   fortwo  smartfortwo
# 16184  [car_ims/016185.jpg]    [[1]]   [[1]]  ...  smart   fortwo  smartfortwo
#
# [16185 rows x 13 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(merged_df_2, test_size = 0.2, random_state = 42)

# %%
train#this dataframe contains the file names of all the images used for training the model
# Out:
#            relative_im_path  bbox_x1  ...       model                  both
# 15775  [car_ims/015776.jpg]  [[296]]  ...      Beetle      volkswagenbeetle
# 6759   [car_ims/006760.jpg]   [[49]]  ...     Caliber          dodgecaliber
# 8875   [car_ims/008876.jpg]   [[17]]  ...  Expedition        fordexpedition
# 8919   [car_ims/008920.jpg]   [[41]]  ...  Expedition        fordexpedition
# 10307  [car_ims/010308.jpg]   [[30]]  ...          H2              hummerh2
# ...                     ...      ...  ...         ...                   ...
# 13418  [car_ims/013419.jpg]  [[166]]  ...     E-Class  mercedes-benze-class
# 5390   [car_ims/005391.jpg]   [[27]]  ...      Malibu       chevroletmalibu
# 860    [car_ims/000861.jpg]   [[43]]  ...      Martin           astonmartin
# 15795  [car_ims/015796.jpg]  [[195]]  ...      Beetle      volkswagenbeetle
# 7270   [car_ims/007271.jpg]  [[198]]  ...     Journey          dodgejourney
#
# [12948 rows x 13 columns]

# %%
carBrand = names_df['both'].unique()

# %%
for b in carBrand:#this loop is used to take a particular image from the car_ims folder, make a copy and put it in the 'train' folder of the particular car it belongs to. Make sure to the unzipped car_ims.tgz file from the Stanford website.
  temp_df = train[train['both']==b]
  temp_df.reset_index(drop = True)
  print(b)
  for i in list(temp_df.index.values):
    shutil.copy('/content/drive/Shareddrives/apm_cnn_trial/trial_2/car_ims/'+temp_df['file_name'][i], '/content/drive/Shareddrives/apm_cnn_trial/trial_2/train_brand_and_model_2/'+b.lower()+'/'+temp_df['file_name'][i])
# Out:
# amgeneral
# acurarl
# acuratl
# acuratsx
# acuraintegra
# acurazdx
# astonmartin
# audirs
# audia5
# auditts
# audir8
# audiv8
# audi100
# auditt
# audis6
# audis5
# audis4
# bmwactivehybrid
# bmw1
# bmw3
# bmw6
# bmwx5
# bmwx6
# bmwm3
# bmwm5
# bmwm6
# bmwx3
# bmwz4
# bentleycontinental
# bentleyarnage
# bentleymulsanne
# bugattiveyron
# buickregal
# buickrainier
# buickverano
# buickenclave
# cadillaccts-v
# cadillacsrx
# cadillacescalade
# chevroletsilverado
# chevroletcorvette
# chevrolettraverse
# chevroletcamaro
# chevrolethhr
# chevroletimpala
# chevrolettahoe
# chevroletsonic
# chevroletexpress
# chevroletavalanche
# chevroletcobalt
# chevroletmalibu
# chevrolettrailblazer
# chevroletmonte
# chrysleraspen
# chryslersebring
# chryslertown
# chrysler300
# chryslercrossfire
# chryslerpt
# daewoonubira
# dodgecaliber
# dodgecaravan
# dodgeram
# dodgesprinter
# dodgejourney
# dodgedakota
# dodgemagnum
# dodgechallenger
# dodgedurango
# dodgecharger
# eagletalon
# fiat500
# ferrariff
# ferraricalifornia
# ferrari458
# fiskerkarma
# fordf-450
# fordmustang
# fordfreestar
# fordexpedition
# fordedge
# fordranger
# fordgt
# fordf-150
# fordfocus
# forde-series
# fordfiesta
# gmcterrain
# gmcsavana
# gmcyukon
# gmcacadia
# gmccanyon
# geometro
# hummerh3t
# hummerh2
# hondaodyssey
# hondaaccord
# hyundaiveloster
# hyundaisanta
# hyundaitucson
# hyundaiveracruz
# hyundaisonata
# hyundaielantra
# hyundaiaccent
# hyundaigenesis
# hyundaiazera
# infinitig
# infinitiqx56
# isuzuascender
# jaguarxk
# jeeppatriot
# jeepwrangler
# jeepliberty
# jeepgrand
# jeepcompass
# lamborghinireventon
# lamborghiniaventador
# lamborghinigallardo
# lamborghinidiablo
# landrover
# lincolntown
# minicooper
# maybachlandaulet
# mazdatribute
# mclarenmp4-12c
# mercedes-benz300-class
# mercedes-benzc-class
# mercedes-benzsl-class
# mercedes-benze-class
# mercedes-benzs-class
# mercedes-benzsprinter
# mitsubishilancer
# nissanleaf
# nissannv
# nissanjuke
# nissan240sx
# plymouthneon
# porschepanamera
# ramcv
# rolls-roycephantom
# rolls-royceghost
# scionxd
# spykerc8
# suzukiaerio
# suzukikizashi
# suzukisx4
# teslamodel
# toyotasequoia
# toyotacamry
# toyotacorolla
# toyota4runner
# volkswagengolf
# volkswagenbeetle
# volvoc30
# volvo240
# volvoxc90
# smartfortwo

# %%
test = test.reset_index(drop = True)
test#this is the dataframe for the test set
# Out:
#           relative_im_path  bbox_x1  ...       model               both
# 0     [car_ims/015759.jpg]   [[46]]  ...        Golf     volkswagengolf
# 1     [car_ims/014970.jpg]   [[95]]  ...     Kizashi      suzukikizashi
# 2     [car_ims/006875.jpg]  [[154]]  ...     Caravan       dodgecaravan
# 3     [car_ims/009759.jpg]   [[19]]  ...      Savana          gmcsavana
# 4     [car_ims/013072.jpg]   [[86]]  ...     MP4-12C     mclarenmp4-12c
# ...                    ...      ...  ...         ...                ...
# 3232  [car_ims/006696.jpg]   [[48]]  ...      Nubira       daewoonubira
# 3233  [car_ims/009437.jpg]   [[29]]  ...       Focus          fordfocus
# 3234  [car_ims/009884.jpg]   [[52]]  ...      Acadia          gmcacadia
# 3235  [car_ims/000511.jpg]   [[95]]  ...         ZDX           acurazdx
# 3236  [car_ims/008269.jpg]   [[36]]  ...  California  ferraricalifornia
#
# [3237 rows x 13 columns]

# %%
for b in carBrand:#this loop is used to take a particular image from the car_ims folder, make a copy and put it in the 'test' folder of the particular car it belongs to.
  temp_df = test[test['both']==b]
  temp_df.reset_index(drop = True)
  print(b)
  for i in list(temp_df.index.values):
    shutil.copy('/content/drive/Shareddrives/apm_cnn_trial/trial_2/car_ims/'+temp_df['file_name'][i], '/content/drive/Shareddrives/apm_cnn_trial/trial_2/test_brand_and_model_2/'+b.lower()+'/'+temp_df['file_name'][i])
# Out:
# amgeneral
# acurarl
# acuratl
# acuratsx
# acuraintegra
# acurazdx
# astonmartin
# audirs
# audia5
# auditts
# audir8
# audiv8
# audi100
# auditt
# audis6
# audis5
# audis4
# bmwactivehybrid
# bmw1
# bmw3
# bmw6
# bmwx5
# bmwx6
# bmwm3
# bmwm5
# bmwm6
# bmwx3
# bmwz4
# bentleycontinental
# bentleyarnage
# bentleymulsanne
# bugattiveyron
# buickregal
# buickrainier
# buickverano
# buickenclave
# cadillaccts-v
# cadillacsrx
# cadillacescalade
# chevroletsilverado
# chevroletcorvette
# chevrolettraverse
# chevroletcamaro
# chevrolethhr
# chevroletimpala
# chevrolettahoe
# chevroletsonic
# chevroletexpress
# chevroletavalanche
# chevroletcobalt
# chevroletmalibu
# chevrolettrailblazer
# chevroletmonte
# chrysleraspen
# chryslersebring
# chryslertown
# chrysler300
# chryslercrossfire
# chryslerpt
# daewoonubira
# dodgecaliber
# dodgecaravan
# dodgeram
# dodgesprinter
# dodgejourney
# dodgedakota
# dodgemagnum
# dodgechallenger
# dodgedurango
# dodgecharger
# eagletalon
# fiat500
# ferrariff
# ferraricalifornia
# ferrari458
# fiskerkarma
# fordf-450
# fordmustang
# fordfreestar
# fordexpedition
# fordedge
# fordranger
# fordgt
# fordf-150
# fordfocus
# forde-series
# fordfiesta
# gmcterrain
# gmcsavana
# gmcyukon
# gmcacadia
# gmccanyon
# geometro
# hummerh3t
# hummerh2
# hondaodyssey
# hondaaccord
# hyundaiveloster
# hyundaisanta
# hyundaitucson
# hyundaiveracruz
# hyundaisonata
# hyundaielantra
# hyundaiaccent
# hyundaigenesis
# hyundaiazera
# infinitig
# infinitiqx56
# isuzuascender
# jaguarxk
# jeeppatriot
# jeepwrangler
# jeepliberty
# jeepgrand
# jeepcompass
# lamborghinireventon
# lamborghiniaventador
# lamborghinigallardo
# lamborghinidiablo
# landrover
# lincolntown
# minicooper
# maybachlandaulet
# mazdatribute
# mclarenmp4-12c
# mercedes-benz300-class
# mercedes-benzc-class
# mercedes-benzsl-class
# mercedes-benze-class
# mercedes-benzs-class
# mercedes-benzsprinter
# mitsubishilancer
# nissanleaf
# nissannv
# nissanjuke
# nissan240sx
# plymouthneon
# porschepanamera
# ramcv
# rolls-roycephantom
# rolls-royceghost
# scionxd
# spykerc8
# suzukiaerio
# suzukikizashi
# suzukisx4
# teslamodel
# toyotasequoia
# toyotacamry
# toyotacorolla
# toyota4runner
# volkswagengolf
# volkswagenbeetle
# volvoc30
# volvo240
# volvoxc90
# smartfortwo
